# %%
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

from wordcloud import WordCloud

#Importing Dataset

df = pd.read_csv("final_less_stopwords.csv")

# %%
from collections import Counter
Counter(" ".join(map(str,df["text"])).split()).most_common(100)
# Out:
# [('pagod', 1108),
#  ('ease', 601),
#  ('pagodnakami', 573),
#  ('time', 560),
#  ('pls', 509),
#  ('online', 465),
#  ('please', 441),
#  ('heed', 418),
#  ('f', 382),
#  ('classes', 377),
#  ('us', 372),
#  ('deped', 346),
#  ('like', 340),
#  ('left', 323),
#  ('join', 320),
#  ('first', 317),
#  ('behind', 311),
#  ('nan', 303),
#  ('community', 281),
#  ('yestoacademicfreeze', 280),
#  ('one', 277),
#  ('university', 275),
#  ('upd', 274),
#  ('amp', 272),
#  ('nostudentleftbehind', 269),
#  ('ayoko', 266),
#  ('e', 257),
#  ('estudyante', 257),
#  ('sign', 256),
#  ('daw', 255),
#  ('tangina', 252),
#  ('petition', 252),
#  ('walangiwananupd', 250),
#  ('tas', 247),
#  ('genuine', 247),
#  ('pasok', 246),
#  ('health', 246),
#  ('ensure', 242),
#  ('stress', 240),
#  ('together', 238),
#  ('bang', 235),
#  ('constituents', 235),
#  ('ched', 233),
#  ('next', 231),
#  ('learning', 231),
#  ('uphold', 226),
#  ('calls', 221),
#  ('aral', 219),
#  ('education', 219),
# ...

# %%
df2 = pd.read_csv("final_clean.csv")

# %%
Counter(" ".join(map(str,df2["text"])).split()).most_common(100)
# Out:
# [('academic', 7419),
#  ('break', 4481),
#  ('co', 3056),
#  ('academicbreaknow', 2791),
#  ('freeze', 2580),
#  ('academiceasenow', 1953),
#  ('academicfreezenow', 1930),
#  ('lang', 1701),
#  ('academicbreak', 1339),
#  ('academicfreeze', 1162),
#  ('pagod', 1108),
#  ('yung', 1089),
#  ('mag', 1053),
#  ('students', 1038),
#  ('naman', 1037),
#  ('wala', 1032),
#  ('po', 961),
#  ('di', 909),
#  ('school', 830),
#  ('call', 785),
#  ('acadbreak', 675),
#  ('ligtasnabalikeskwela', 660),
#  ('ba', 643),
#  ('nag', 626),
#  ('talaga', 624),
#  ('ease', 601),
#  ('week', 600),
#  ('pagodnakami', 573),
#  ('time', 560),
#  ('student', 515),
#  ('kasi', 511),
#  ('need', 509),
#  ('pls', 509),
#  ('tapos', 480),
#  ('nga', 473),
#  ('mo', 471),
#  ('online', 465),
#  ('kayo', 463),
#  ('pag', 442),
#  ('class', 441),
#  ('please', 441),
#  ('day', 435),
#  ('niyo', 419),
#  ('heed', 418),
#  ('sana', 413),
#  ('f', 382),
#  ('classes', 377),
#  ('agad', 373),
#  ('year', 373),
# ...
