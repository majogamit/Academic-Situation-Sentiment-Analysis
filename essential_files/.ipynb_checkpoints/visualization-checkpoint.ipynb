# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt

# Data for dataset LSTM
train_accuracy_1 = 0.9399
val_accuracy_1 = 0.7584

# Data for Bilstm imbalanced
train_accuracy_2 = 0.9535
val_accuracy_2 = 0.7508

# Data for lstm balanced
train_accuracy_3 = 0.9870
val_accuracy_3 = 0.8082


# Data for Bilstm balanced
train_accuracy_4 = 0.9885
val_accuracy_4 = 0.8044



# LSTM
x = ['LSTM Imbalanced', 'BiLSTM Imbalanced', 'LSTM Balanced', 'BiLSTM Balanced']
lstm_u = [train_accuracy_1, train_accuracy_2,train_accuracy_3, train_accuracy_4]
bilstm_u = [val_accuracy_1, val_accuracy_2, val_accuracy_3, val_accuracy_4]


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(x, lstm_u, color='#295f48', label='Training')
ax.bar(x, bilstm_u, color='pink', label='Validation')
plt.legend(loc='lower left')
plt.xlabel('Model and Dataset')
plt.ylabel('Accuracy')
for i in range(len(x)):
    ax.text(i-0.2, lstm_u[i] - 0.05, str(lstm_u[i]), color='white', fontweight='bold')
    ax.text(i-0.2, bilstm_u[i] - 0.05, str(bilstm_u[i]), color='black', fontweight='bold')


# plt.title('Training And Testing Accuracy of LSTM and BiLSTM on Imbalanced and Balanced Datasets')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for four datasets
train_accuracy_1 = 0.9399
val_accuracy_1 = 0.7584

# Data for Bilstm imbalanced
train_accuracy_2 = 0.9535
val_accuracy_2 = 0.7508

# Data for lstm balanced
train_accuracy_3 = 0.9870
val_accuracy_3 = 0.8082


# Data for Bilstm balanced
train_accuracy_4 = 0.9885
val_accuracy_4 = 0.8044

# Plotting the accuracy of each dataset
datasets = ['Dataset 1', 'Dataset 2', 'Dataset 3', 'Dataset 4']
train_acc = [train_accuracy_1, train_accuracy_2,train_accuracy_3, train_accuracy_4]
val_acc =  [val_accuracy_1, val_accuracy_2, val_accuracy_3, val_accuracy_4]


x = [i for i, _ in enumerate(datasets)]

plt.bar(x, train_acc, width=0.4, label='Training Accuracy')
plt.bar([i + 0.4 for i in x], val_acc, width=0.4, label='Validation Accuracy')

plt.xticks([i + 0.2 for i in x], datasets)
plt.xlabel('Datasets')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")

# Add text labels to the bars
for i in range(len(train_acc)):
    plt.text(x[i] - 0.2, train_acc[i] + 0.01, str(train_acc[i]), color='black', fontweight='bold')
    plt.text(x[i] + 0.2, val_acc[i] + 0.01, str(val_acc[i]), color='black', fontweight='bold')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for dataset LSTM

val_accuracy_1 = 0.5646 

# Data for Bilstm imbalanced

val_accuracy_2 = 0.5727

# Data for lstm balanced

val_accuracy_3 = 0.5071


# Data for Bilstm balanced

val_accuracy_4 = 0.5222



# LSTM
x = ['LSTM Imbalanced', 'BiLSTM Imbalanced', 'LSTM Balanced', 'BiLSTM Balanced']

bilstm_u = [val_accuracy_1, val_accuracy_2, val_accuracy_3, val_accuracy_4]


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(x, bilstm_u, color='pink', label='Validation')
plt.legend(loc='lower left')
plt.xlabel('Model and Dataset')
plt.ylabel('Accuracy')
for i in range(len(x)):
    ax.text(i-0.2, bilstm_u[i] - 0.05, str(bilstm_u[i]), color='black', fontweight='bold')


# plt.title('Training And Testing Accuracy of LSTM and BiLSTM on Imbalanced and Balanced Datasets')
plt.show()
