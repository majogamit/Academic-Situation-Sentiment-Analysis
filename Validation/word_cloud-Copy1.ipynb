# %%
from nltk.tokenize.toktok import ToktokTokenizer

# %%
#Importing Libraries

import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

from wordcloud import WordCloud

#Importing Dataset

df = pd.read_csv("final_clean.csv")

#Checking the Data

df.head()

#Creating the text variable

text2 = " ".join(title for title in df.text)

# Creating word_cloud with text as argument in .generate() method

word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

# Display the generated Word Cloud
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
academic_stopwords = ['academic', 'academiceasenow', 'academicbreaknow', 'break', 'academicfreezenow', 'academicfreeze', 'freeze', 'ligtasnabalikeskwela', 'student', 'school', 'yung', 'di', 'co', 'naman', 'academicbreak', 'lang', 'po', 'nag', 'mag', 'pag', 'tapos', 'talaga', 'agad', 'week', 'nga', 'mo', 'muna', 'student', 'class', 'kayo', 'palang', 'nalang', 'students', 'call', 'need', 'year', 'eh', 'ta', 'u', 'yan', 'pala', 'niyo', 'parang', 'rin', 'din', 'si', 'acadbreak', 'wala', 'ba', 'day', 'kasi', 'sana', 'niyo', 'akong', 'nyo']

# %%
tokenizer = ToktokTokenizer()
def remove_academic_stopwords(text):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token.lower() not in academic_stopwords]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

df['text']=df['text'].apply(remove_academic_stopwords)

# %%
df
# Out:
#                                                   text  Unnamed: 1  sentiment
# 0                                  lunes nanaman bukas         NaN          0
# 1                                  q tapusin wednesday         NaN          0
# 2                                 super delay tbw list         NaN          0
# 3                              tsngina pagod magpaypay         NaN          0
# 4    pagoda accla hours tulog gising lecture practi...         NaN          0
# ..                                                 ...         ...        ...
# 995  withhighhonor congratulations fellow graduates...         NaN          1
# 996                         congrats sating yes honors         NaN          1
# 997  days covid finally feel healthy enough back wo...         NaN          1
# 998  nagrereklamo ayaw pumasok honors ate thank lor...         NaN          1
# 999    moving recognition ceremony congrats completers         NaN          1
#
# [1000 rows x 3 columns]

# %%
text2 = " ".join(title for title in df.text)

# Creating word_cloud with text as argument in .generate() method

word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

# Display the generated Word Cloud
plt.figure(figsize = (10, 10), facecolor = None)
plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
df = df.iloc[: , 1:]

# %%
df.to_csv('final_less_stopwords.csv')

# %%
df.head()
# Out:
#    Unnamed: 1  sentiment
# 0         NaN          0
# 1         NaN          0
# 2         NaN          0
# 3         NaN          0
# 4         NaN          0
