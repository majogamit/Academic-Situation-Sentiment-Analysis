# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### Import Libraries

# %%
# main libraries
import numpy as np
import pandas as pd
import nltk

# For Data processing/cleaning
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import STOPWORDS
from bs4 import BeautifulSoup
import re
from nltk.tokenize.toktok import ToktokTokenizer
import os
import warnings

# %%
# import sys
# sys.path.append("stemmer\TagalogStemmerPython")

# import TglStemmer

# %%
dataset = pd.read_csv("nlp_research_dataset_1000.csv")

# %%
dataset.shape
# Out:
# (1000, 4)

# %%
dataset.head()
# Out:
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
#
#                                                 text  label
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1

# %%
dataset.isna().any()
# Out:
# date     False
# user     False
# text     False
# label    False
# dtype: bool

# %%
# df2 = dataset.drop_duplicates(subset=["text"], keep='first')
# df2.shape
df2 = dataset[:]

# %% [markdown]
# ### Removing @names

# %%
def remove_pattern(text,pattern):
    
    # re.findall() finds the pattern i.e @user and puts it in a list for further task
    r = re.findall(pattern,text)
    
    # re.sub() removes @user from the sentences in the dataset
    for i in r:
        text = re.sub(i,"",text)
    
    return text

# %%
df2['tidy_tweets'] = np.vectorize(remove_pattern)(df2['text'], "@[\w]*")

df2.head(10)
# Out:
# <ipython-input-9-7ce2c0ade8c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['tidy_tweets'] = np.vectorize(remove_pattern)(df2['text'], "@[\w]*")
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
# 5  2022-11-22 15:31:24+00:00   rielles_cart
# 6  2022-11-22 14:27:37+00:00       aziallaa
# 7  2022-11-21 14:33:33+00:00        joluvre
# 8  2022-11-20 15:44:32+00:00         k0_aly
# 9  2022-11-20 14:26:29+00:00      mxmoonlee
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# 5  sa letra ng p, putangina pagod na ko #academic...     -1
# 6  nakalimutan kong may coffee pala ako kasi may ...     -1
# 7  @tkluvon itâ€™s so hard to keep up gawa ng sch...     -1
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...     -1
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...     -1
#
#                                          tidy_tweets
# 0              lunes nanaman bukas #academicbreaknow
# 1     #AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko #academicbre...
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...
# 5  sa letra ng p, putangina pagod na ko #academic...
# 6  nakalimutan kong may coffee pala ako kasi may ...
# 7   itâ€™s so hard to keep up gawa ng school late...
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...

# %% [markdown]
# ###  Removing Punctuations, Numbers, and Special Characters

# %%
df2['tidy_tweets'] = df2['tidy_tweets'].str.replace("[^a-zA-Z#]", " ")
df2.head(10)
# Out:
# <ipython-input-10-58216521fa57>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['tidy_tweets'] = df2['tidy_tweets'].str.replace("[^a-zA-Z#]", " ")
# <ipython-input-10-58216521fa57>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['tidy_tweets'] = df2['tidy_tweets'].str.replace("[^a-zA-Z#]", " ")
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
# 5  2022-11-22 15:31:24+00:00   rielles_cart
# 6  2022-11-22 14:27:37+00:00       aziallaa
# 7  2022-11-21 14:33:33+00:00        joluvre
# 8  2022-11-20 15:44:32+00:00         k0_aly
# 9  2022-11-20 14:26:29+00:00      mxmoonlee
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# 5  sa letra ng p, putangina pagod na ko #academic...     -1
# 6  nakalimutan kong may coffee pala ako kasi may ...     -1
# 7  @tkluvon itâ€™s so hard to keep up gawa ng sch...     -1
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...     -1
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...     -1
#
#                                          tidy_tweets
# 0              lunes nanaman bukas #academicbreaknow
# 1     #AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko #academicbre...
# 3  # academicbreaknow tsngina pagod na  ko magpaypay
# 4  Pagoda ang accla   hours tulog gising     am l...
# 5  sa letra ng p  putangina pagod na ko #academic...
# 6  nakalimutan kong may coffee pala ako kasi may ...
# 7   it   s so hard to keep up gawa ng school late...
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...
# 9  #AcademicBreakNow I don   t have time for Enhy...

# %% [markdown]
# ### Removing links

# %%
cleaned_tweets = []

for index, row in df2.iterrows():
    # Here we are filtering out all the words that contains link
    words_without_links = [word for word in row.tidy_tweets.split() if 'http' not in word]
    cleaned_tweets.append(' '.join(words_without_links))

df2['tidy_tweets'] = cleaned_tweets
df2.head(10)
# Out:
# <ipython-input-11-e81f0b0f3605>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['tidy_tweets'] = cleaned_tweets
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
# 5  2022-11-22 15:31:24+00:00   rielles_cart
# 6  2022-11-22 14:27:37+00:00       aziallaa
# 7  2022-11-21 14:33:33+00:00        joluvre
# 8  2022-11-20 15:44:32+00:00         k0_aly
# 9  2022-11-20 14:26:29+00:00      mxmoonlee
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# 5  sa letra ng p, putangina pagod na ko #academic...     -1
# 6  nakalimutan kong may coffee pala ako kasi may ...     -1
# 7  @tkluvon itâ€™s so hard to keep up gawa ng sch...     -1
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...     -1
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...     -1
#
#                                          tidy_tweets
# 0              lunes nanaman bukas #academicbreaknow
# 1     #AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko #academicbre...
# 3   # academicbreaknow tsngina pagod na ko magpaypay
# 4  Pagoda ang accla hours tulog gising am lecture...
# 5  sa letra ng p putangina pagod na ko #academicb...
# 6  nakalimutan kong may coffee pala ako kasi may ...
# 7  it s so hard to keep up gawa ng school lately ...
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...
# 9  #AcademicBreakNow I don t have time for Enhype...

# %% [markdown]
# ### Remove hashtags

# %%
def clean_char(text):
    clean_tweet = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    return clean_tweet
df2['tidy_tweets']=df2['tidy_tweets'].apply(clean_char)
# Out:
# <ipython-input-12-82c43afc332d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['tidy_tweets']=df2['tidy_tweets'].apply(clean_char)

# %%
df2.head(10)
# Out:
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
# 5  2022-11-22 15:31:24+00:00   rielles_cart
# 6  2022-11-22 14:27:37+00:00       aziallaa
# 7  2022-11-21 14:33:33+00:00        joluvre
# 8  2022-11-20 15:44:32+00:00         k0_aly
# 9  2022-11-20 14:26:29+00:00      mxmoonlee
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# 5  sa letra ng p, putangina pagod na ko #academic...     -1
# 6  nakalimutan kong may coffee pala ako kasi may ...     -1
# 7  @tkluvon itâ€™s so hard to keep up gawa ng sch...     -1
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...     -1
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...     -1
#
#                                          tidy_tweets
# 0               lunes nanaman bukas academicbreaknow
# 1      AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko academicbrea...
# 3     academicbreaknow tsngina pagod na ko magpaypay
# 4  Pagoda ang accla hours tulog gising am lecture...
# 5  sa letra ng p putangina pagod na ko academicbr...
# 6  nakalimutan kong may coffee pala ako kasi may ...
# 7  it s so hard to keep up gawa ng school lately ...
# 8  Nakakapagod na mag buhat ng mabigat na bag Aca...
# 9  AcademicBreakNow I don t have time for Enhypen...

# %% [markdown]
# ### Remove rows with empty texts

# %%
tweets_df = df2[df2['tidy_tweets']!='']
tweets_df.head(10)
# Out:
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
# 5  2022-11-22 15:31:24+00:00   rielles_cart
# 6  2022-11-22 14:27:37+00:00       aziallaa
# 7  2022-11-21 14:33:33+00:00        joluvre
# 8  2022-11-20 15:44:32+00:00         k0_aly
# 9  2022-11-20 14:26:29+00:00      mxmoonlee
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# 5  sa letra ng p, putangina pagod na ko #academic...     -1
# 6  nakalimutan kong may coffee pala ako kasi may ...     -1
# 7  @tkluvon itâ€™s so hard to keep up gawa ng sch...     -1
# 8  Nakakapagod na mag buhat ng mabigat na bag #Ac...     -1
# 9  #AcademicBreakNow I donâ€™t have time for Enhy...     -1
#
#                                          tidy_tweets
# 0               lunes nanaman bukas academicbreaknow
# 1      AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko academicbrea...
# 3     academicbreaknow tsngina pagod na ko magpaypay
# 4  Pagoda ang accla hours tulog gising am lecture...
# 5  sa letra ng p putangina pagod na ko academicbr...
# 6  nakalimutan kong may coffee pala ako kasi may ...
# 7  it s so hard to keep up gawa ng school lately ...
# 8  Nakakapagod na mag buhat ng mabigat na bag Aca...
# 9  AcademicBreakNow I don t have time for Enhypen...

# %% [markdown]
# ### Drop Duplicates

# %%
# tweets_df.drop_duplicates(subset=['tidy_tweets'], keep='first')
# tweets_df.shape

# %% [markdown]
# ### Reset Index

# %%
tweets_df = tweets_df.reset_index(drop=True)
tweets_df
# Out:
#                           date            user  \
# 0    2022-11-27 10:30:42+00:00       dprleanne
# 1    2022-11-27 09:02:47+00:00     ericakieraa
# 2    2022-11-25 13:30:42+00:00         qin_ina
# 3    2022-11-24 12:46:22+00:00       _patreng_
# 4    2022-11-24 08:18:08+00:00   willowveewise
# ..                         ...             ...
# 995  2021-07-15 04:49:56+00:00    Caipaparazii
# 996  2021-07-14 18:27:03+00:00   jeveuxxmourir
# 997  2021-06-21 09:05:07+00:00  A_curiouspanda
# 998  2021-06-12 02:46:24+00:00    seokjinbi1og
# 999  2021-05-21 03:52:44+00:00       stfuken77
#
#                                                   text  label  \
# 0                lunes nanaman bukas #academicbreaknow     -1
# 1       #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2    super delay na ako sa tbw list ko #academicbre...     -1
# 3    #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4    Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# ..                                                 ...    ...
# 995  From #AcademicFreeze to #WithHighHonor Congrat...      1
# 996  @vvrill_ congrats sating Yes to Academic Freez...      1
# 997  After 17 days of covid, I finally feel healthy...      1
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...      1
# 999  from: "academic freeze now!"\nto: Moving Up an...      1
#
#                                            tidy_tweets
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising am lecture...
# ..                                                 ...
# 995  From AcademicFreeze to WithHighHonor Congratul...
# 996  congrats sating Yes to Academic Freeze pero wi...
# 997  After days of covid I finally feel healthy eno...
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...
# 999  from academic freeze now to Moving Up and Reco...
#
# [1000 rows x 5 columns]

# %%
tweets_df.shape
# Out:
# (1000, 5)

# %% [markdown]
# ### Remove special characters again

# %%
tweets_df['absolute_tidy_tweets'] = tweets_df['tidy_tweets'].str.replace("[^a-zA-Z# ]", " ")
# Out:
# <ipython-input-18-cbb8feb682c4>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df['absolute_tidy_tweets'] = tweets_df['tidy_tweets'].str.replace("[^a-zA-Z# ]", " ")

# %%
tweets_df
# Out:
#                           date            user  \
# 0    2022-11-27 10:30:42+00:00       dprleanne
# 1    2022-11-27 09:02:47+00:00     ericakieraa
# 2    2022-11-25 13:30:42+00:00         qin_ina
# 3    2022-11-24 12:46:22+00:00       _patreng_
# 4    2022-11-24 08:18:08+00:00   willowveewise
# ..                         ...             ...
# 995  2021-07-15 04:49:56+00:00    Caipaparazii
# 996  2021-07-14 18:27:03+00:00   jeveuxxmourir
# 997  2021-06-21 09:05:07+00:00  A_curiouspanda
# 998  2021-06-12 02:46:24+00:00    seokjinbi1og
# 999  2021-05-21 03:52:44+00:00       stfuken77
#
#                                                   text  label  \
# 0                lunes nanaman bukas #academicbreaknow     -1
# 1       #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2    super delay na ako sa tbw list ko #academicbre...     -1
# 3    #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4    Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# ..                                                 ...    ...
# 995  From #AcademicFreeze to #WithHighHonor Congrat...      1
# 996  @vvrill_ congrats sating Yes to Academic Freez...      1
# 997  After 17 days of covid, I finally feel healthy...      1
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...      1
# 999  from: "academic freeze now!"\nto: Moving Up an...      1
#
#                                            tidy_tweets  \
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising am lecture...
# ..                                                 ...
# 995  From AcademicFreeze to WithHighHonor Congratul...
# 996  congrats sating Yes to Academic Freeze pero wi...
# 997  After days of covid I finally feel healthy eno...
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...
# 999  from academic freeze now to Moving Up and Reco...
#
#                                   absolute_tidy_tweets
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising am lecture...
# ..                                                 ...
# 995  From AcademicFreeze to WithHighHonor Congratul...
# 996  congrats sating Yes to Academic Freeze pero wi...
# 997  After days of covid I finally feel healthy eno...
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...
# 999  from academic freeze now to Moving Up and Reco...
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Remove English and Filipino Stopwords

# %%
tokenizer = ToktokTokenizer()

# %%
stopword_eng = nltk.corpus.stopwords.words('english')
stopword_fil = ["akin","aking","ako","alin","am","amin","aming","ang","ano","anumang","apat","at","atin","ating","ay","bababa","bago","bakit","bawat","bilang","dahil","dalawa","dapat","din","dito","doon","gagawin","gayunman","ginagawa","ginawa","ginawang","gumawa","gusto","habang","hanggang","hindi","huwag","iba","ibaba","ibabaw","ibig","ikaw","ilagay","ilalim","ilan","inyong","isa","isang","itaas","ito","iyo","iyon","iyong","ka","kahit","kailangan","kailanman","kami","kanila","kanilang","kanino","kanya","kanyang","kapag","kapwa","karamihan","katiyakan","katulad","kaya","kaysa","ko","kong","kulang","kumuha","kung","laban","lahat","lamang","likod","lima","maaari","maaaring","maging","mahusay","makita","marami","marapat","masyado","may","mayroon","mga","minsan","mismo","mula","muli","na","nabanggit","naging","nagkaroon","nais","nakita","namin","napaka","narito","nasaan","ng","ngayon","ni","nila","nilang","nito","niya","niyang","noon","o","pa","paano","pababa","paggawa","pagitan","pagkakaroon","pagkatapos","palabas","pamamagitan","panahon","pangalawa","para","paraan","pareho","pataas","pero","pumunta","pumupunta","sa","saan","sabi","sabihin","sarili","sila","sino","siya","tatlo","tayo","tulad","tungkol","una","walang"]

# %%
print(stopword_eng)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
print(stopword_fil)
# Out:
# ['akin', 'aking', 'ako', 'alin', 'am', 'amin', 'aming', 'ang', 'ano', 'anumang', 'apat', 'at', 'atin', 'ating', 'ay', 'bababa', 'bago', 'bakit', 'bawat', 'bilang', 'dahil', 'dalawa', 'dapat', 'din', 'dito', 'doon', 'gagawin', 'gayunman', 'ginagawa', 'ginawa', 'ginawang', 'gumawa', 'gusto', 'habang', 'hanggang', 'hindi', 'huwag', 'iba', 'ibaba', 'ibabaw', 'ibig', 'ikaw', 'ilagay', 'ilalim', 'ilan', 'inyong', 'isa', 'isang', 'itaas', 'ito', 'iyo', 'iyon', 'iyong', 'ka', 'kahit', 'kailangan', 'kailanman', 'kami', 'kanila', 'kanilang', 'kanino', 'kanya', 'kanyang', 'kapag', 'kapwa', 'karamihan', 'katiyakan', 'katulad', 'kaya', 'kaysa', 'ko', 'kong', 'kulang', 'kumuha', 'kung', 'laban', 'lahat', 'lamang', 'likod', 'lima', 'maaari', 'maaaring', 'maging', 'mahusay', 'makita', 'marami', 'marapat', 'masyado', 'may', 'mayroon', 'mga', 'minsan', 'mismo', 'mula', 'muli', 'na', 'nabanggit', 'naging', 'nagkaroon', 'nais', 'nakita', 'namin', 'napaka', 'narito', 'nasaan', 'ng', 'ngayon', 'ni', 'nila', 'nilang', 'nito', 'niya', 'niyang', 'noon', 'o', 'pa', 'paano', 'pababa', 'paggawa', 'pagitan', 'pagkakaroon', 'pagkatapos', 'palabas', 'pamamagitan', 'panahon', 'pangalawa', 'para', 'paraan', 'pareho', 'pataas', 'pero', 'pumunta', 'pumupunta', 'sa', 'saan', 'sabi', 'sabihin', 'sarili', 'sila', 'sino', 'siya', 'tatlo', 'tayo', 'tulad', 'tungkol', 'una', 'walang']

# %% [markdown]
# ### Remove english stopwords

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_eng]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_eng]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

tweets_df['stopped_tweets']=tweets_df['absolute_tidy_tweets'].apply(remove_stopwords)

# %%
tweets_df
# Out:
#                           date            user  \
# 0    2022-11-27 10:30:42+00:00       dprleanne
# 1    2022-11-27 09:02:47+00:00     ericakieraa
# 2    2022-11-25 13:30:42+00:00         qin_ina
# 3    2022-11-24 12:46:22+00:00       _patreng_
# 4    2022-11-24 08:18:08+00:00   willowveewise
# ..                         ...             ...
# 995  2021-07-15 04:49:56+00:00    Caipaparazii
# 996  2021-07-14 18:27:03+00:00   jeveuxxmourir
# 997  2021-06-21 09:05:07+00:00  A_curiouspanda
# 998  2021-06-12 02:46:24+00:00    seokjinbi1og
# 999  2021-05-21 03:52:44+00:00       stfuken77
#
#                                                   text  label  \
# 0                lunes nanaman bukas #academicbreaknow     -1
# 1       #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2    super delay na ako sa tbw list ko #academicbre...     -1
# 3    #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4    Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
# ..                                                 ...    ...
# 995  From #AcademicFreeze to #WithHighHonor Congrat...      1
# 996  @vvrill_ congrats sating Yes to Academic Freez...      1
# 997  After 17 days of covid, I finally feel healthy...      1
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...      1
# 999  from: "academic freeze now!"\nto: Moving Up an...      1
#
#                                            tidy_tweets  \
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising am lecture...
# ..                                                 ...
# 995  From AcademicFreeze to WithHighHonor Congratul...
# 996  congrats sating Yes to Academic Freeze pero wi...
# 997  After days of covid I finally feel healthy eno...
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...
# 999  from academic freeze now to Moving Up and Reco...
#
#                                   absolute_tidy_tweets  \
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising am lecture...
# ..                                                 ...
# 995  From AcademicFreeze to WithHighHonor Congratul...
# 996  congrats sating Yes to Academic Freeze pero wi...
# 997  After days of covid I finally feel healthy eno...
# 998  nagrereklamo pa ko na ayaw ko pumasok at mag a...
# 999  from academic freeze now to Moving Up and Reco...
#
#                                         stopped_tweets
# 0                 lunes nanaman bukas academicbreaknow
# 1        AcademicBreakNow gusto q na tapusin Wednesday
# 2    super delay na ako sa tbw list ko academicbrea...
# 3       academicbreaknow tsngina pagod na ko magpaypay
# 4    Pagoda ang accla hours tulog gising lecture ng...
# ..                                                 ...
# 995  AcademicFreeze WithHighHonor Congratulations f...
# 996    congrats sating Yes Academic Freeze pero Honors
# 997  days covid finally feel healthy enough back wo...
# 998  nagrereklamo pa ko na ayaw ko pumasok mag acad...
# 999  academic freeze Moving Recognition ceremony CO...
#
# [1000 rows x 7 columns]

# %% [markdown]
# ### Remove Filipino Stopwords

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_fil]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_fil]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text.lower()

tweets_df['stopped_tweets']=tweets_df['stopped_tweets'].apply(remove_stopwords)

# %% [markdown]
# ## export to csv for backup

# %%
tweets_df.to_csv('02_Data_wo_Stopwords.csv')

# %% [markdown]
# ## Label Sentiments Automatically

# %% [markdown]
# Compare Textblob and NLTK Sentiment analyzer

# %%
# from textblob import TextBlob
# from textblob.sentiments import NaiveBayesAnalyzer
# from textblob.np_extractors import ConllExtractor

# def fetch_sentiment_using_textblob(text):
#     analysis = TextBlob(text)
#     return 'pos' if analysis.sentiment.polarity >= 0 else 'neg'

# %%
# sentiments_using_textblob = tweets_df.text.apply(lambda tweet: fetch_sentiment_using_textblob(tweet))
# tweets_df['sentiment'] = sentiments_using_textblob
# pd.DataFrame(sentiments_using_textblob.value_counts())

# %%
# from nltk.sentiment.vader import SentimentIntensityAnalyzer

# def fetch_sentiment_using_SIA(text):
#     sid = SentimentIntensityAnalyzer()
#     polarity_scores = sid.polarity_scores(text)
#     return 'neg' if polarity_scores['neg'] > polarity_scores['pos'] else 'pos'

# %%
# sentiments_using_SIA = tweets_df.text.apply(lambda tweet: fetch_sentiment_using_SIA(tweet))
# tweets_df['sentiment'] = sentiments_using_SIA
# pd.DataFrame(sentiments_using_SIA.value_counts())

# %%
# tweets_df.loc[tweets_df.sentiment == 'neg']

# %% [markdown]
# ### Export to csv

# %%
tweets_df.to_csv('03_Data_with_sentiment.csv')

# %%
tweets_df.head()
# Out:
#                         date           user  \
# 0  2022-11-27 10:30:42+00:00      dprleanne
# 1  2022-11-27 09:02:47+00:00    ericakieraa
# 2  2022-11-25 13:30:42+00:00        qin_ina
# 3  2022-11-24 12:46:22+00:00      _patreng_
# 4  2022-11-24 08:18:08+00:00  willowveewise
#
#                                                 text  label  \
# 0              lunes nanaman bukas #academicbreaknow     -1
# 1     #AcademicBreakNow gusto q na tapusin Wednesday     -1
# 2  super delay na ako sa tbw list ko #academicbre...     -1
# 3  #/academicbreaknow tsngina pagod na 'ko magpaypay     -1
# 4  Pagoda ang accla, 4hours tulog gising 3:40am l...     -1
#
#                                          tidy_tweets  \
# 0               lunes nanaman bukas academicbreaknow
# 1      AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko academicbrea...
# 3     academicbreaknow tsngina pagod na ko magpaypay
# 4  Pagoda ang accla hours tulog gising am lecture...
#
#                                 absolute_tidy_tweets  \
# 0               lunes nanaman bukas academicbreaknow
# 1      AcademicBreakNow gusto q na tapusin Wednesday
# 2  super delay na ako sa tbw list ko academicbrea...
# 3     academicbreaknow tsngina pagod na ko magpaypay
# 4  Pagoda ang accla hours tulog gising am lecture...
#
#                                       stopped_tweets
# 0               lunes nanaman bukas academicbreaknow
# 1               academicbreaknow q tapusin wednesday
# 2              super delay tbw list academicbreaknow
# 3           academicbreaknow tsngina pagod magpaypay
# 4  pagoda accla hours tulog gising lecture practi...

# %%
academic_stopwords = ['academic', 'academiceasenow', 'academicbreaknow', 'break', 'academicfreezenow', 'academicfreeze', 'freeze', 'ligtasnabalikeskwela', 'student', 'school', 'yung', 'di', 'co', 'naman', 'academicbreak', 'lang', 'po', 'nag', 'mag', 'pag', 'tapos', 'talaga', 'agad', 'week', 'nga', 'mo', 'muna', 'student', 'class', 'kayo', 'palang', 'nalang', 'students', 'call', 'need', 'year', 'eh', 'ta', 'u', 'yan', 'pala', 'niyo', 'parang', 'rin', 'din', 'si', 'acadbreak', 'wala', 'ba', 'day', 'kasi', 'sana', 'niyo', 'akong', 'nyo']

# %%
df = tweets_df[['stopped_tweets', 'label']]

# %%
tokenizer = ToktokTokenizer()
def remove_academic_stopwords(text):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token.lower() not in academic_stopwords]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

df['stopped_tweets']=df['stopped_tweets'].apply(remove_academic_stopwords)
# Out:
# <ipython-input-37-2dd98a0cbc43>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stopped_tweets']=df['stopped_tweets'].apply(remove_academic_stopwords)

# %%
df
# Out:
#                                         stopped_tweets  label
# 0                                  lunes nanaman bukas     -1
# 1                                  q tapusin wednesday     -1
# 2                                 super delay tbw list     -1
# 3                              tsngina pagod magpaypay     -1
# 4    pagoda accla hours tulog gising lecture practi...     -1
# ..                                                 ...    ...
# 995  withhighhonor congratulations fellow graduates...      1
# 996                         congrats sating yes honors      1
# 997  days covid finally feel healthy enough back wo...      1
# 998  nagrereklamo ayaw pumasok honors ate thank lor...      1
# 999    moving recognition ceremony congrats completers      1
#
# [1000 rows x 2 columns]

# %%
df = df.replace(-1,0)

# %%
df.head()
# Out:
#                                       stopped_tweets  label
# 0                                lunes nanaman bukas      0
# 1                                q tapusin wednesday      0
# 2                               super delay tbw list      0
# 3                            tsngina pagod magpaypay      0
# 4  pagoda accla hours tulog gising lecture practi...      0

# %%
df.columns = ['text', 'sentiment']

# %%
df
# Out:
#                                                   text  sentiment
# 0                                  lunes nanaman bukas          0
# 1                                  q tapusin wednesday          0
# 2                                 super delay tbw list          0
# 3                              tsngina pagod magpaypay          0
# 4    pagoda accla hours tulog gising lecture practi...          0
# ..                                                 ...        ...
# 995  withhighhonor congratulations fellow graduates...          1
# 996                         congrats sating yes honors          1
# 997  days covid finally feel healthy enough back wo...          1
# 998  nagrereklamo ayaw pumasok honors ate thank lor...          1
# 999    moving recognition ceremony congrats completers          1
#
# [1000 rows x 2 columns]

# %%
df.to_csv('final_less_stopwords.csv')
